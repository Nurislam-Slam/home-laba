# %% [markdown]
# # Kazakhstan Climate Change Research Project

# %% [markdown]
# ```
#     The main goal of this project is to analyze how the climate in Kazakhstan is changing over time
# and to explore regional climate trends. My hypothesis is that global warming affects Kazakhstan
# faster than many other regions.
# ```

# %% [markdown]
# ### Project Plan
#
# 1. Load historical weather data using Meteostat.
# 2. Select meteorological stations covering different regions of Kazakhstan.
# 3. Compare Kazakhstan’s climate data with Europe and the USA.

# %% [markdown]
# #### Load weather information

# %%
import pandas as pd
from meteostat import Stations

# %%
stations = Stations()
stations = stations.region('KZ')

'Stations in KZ:', stations.count()
# Out:
# ('Stations in KZ:', 129)

# %%
meteostations = stations.fetch()

# %%
meteostations.head()
# Out:
#                            name country region    wmo  icao  latitude  \
# id
# 28676  Petropavlovsk / Bishkul'      KZ    SEV  28676  <NA>   54.7925
# 28679             Petropavlovsk      KZ    SEV  28679  UACP   54.8333
# 28687        Bulayevo / B?laevo      KZ    SEV  28687  <NA>   54.9000
# 28766            Blacoveschenka      KZ    SEV  28766  <NA>   54.3667
# 28867                    Uricky      KZ    KUS  28867  <NA>   53.3167
#
#        longitude  elevation        timezone hourly_start hourly_end  \
# id
# 28676    69.1178       91.0     Asia/Almaty          NaT        NaT
# 28679    69.1500      136.0  Asia/Qyzylorda   2005-01-01 2025-12-09
# 28687    70.4500      134.0  Asia/Qyzylorda   1959-01-01 2021-01-02
# 28766    66.9667      153.0  Asia/Qyzylorda   1948-01-01 2025-04-02
# 28867    65.5500      210.0     Asia/Aqtobe   1953-02-16 2025-04-02
#
#       daily_start  daily_end monthly_start monthly_end
# id
# 28676  1890-11-19 2025-08-22    1890-01-01  2021-01-01
# 28679  2020-01-18 2022-04-01    1994-01-01  2012-01-01
# 28687  1955-01-01 2020-12-31    1955-01-01  2020-01-01
# 28766  1936-10-01 2021-03-18    1936-01-01  2021-01-01
# 28867  1937-01-01 2021-06-25    1937-01-01  2021-01-01

# %%
meteostations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129 entries, 28676 to UAUU0
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           129 non-null    object
#  1   country        129 non-null    string
#  2   region         129 non-null    string
#  3   wmo            120 non-null    string
#  4   icao           19 non-null     string
#  5   latitude       129 non-null    float64
#  6   longitude      129 non-null    float64
#  7   elevation      129 non-null    float64
#  8   timezone       129 non-null    string
#  9   hourly_start   104 non-null    datetime64[ns]
#  10  hourly_end     104 non-null    datetime64[ns]
#  11  daily_start    128 non-null    datetime64[ns]
#  12  daily_end      128 non-null    datetime64[ns]
#  13  monthly_start  126 non-null    datetime64[ns]
#  14  monthly_end    126 non-null    datetime64[ns]
# dtypes: datetime64[ns](6), float64(3), object(1), string(5)
# memory usage: 16.1+ KB

# %% [markdown]
# ### For better coverage and data continuity, I selected a set of stations using their WMO IDs:
#
# | name          | country | region | wmo   | latitude | longitude | elevation | timezone        | hourly_start | hourly_end  |
# |---------------|---------|--------|-------|----------|-----------|-----------|------------------|--------------|-------------|
# | Shymkent      | KZ      | YUZ    | 38328 | 42,3167  | 69,7      | 552       | Asia/Qyzylorda   | 01.01.1948   | 22.11.2025  |
# | Semipalatinsk | KZ      | VOS    | 36177 | 50,4167  | 80,3      | 196       | Asia/Almaty      | 01.01.1932   | 22.11.2025  |
# | Aktjubinsk    | KZ      | AKT    | 35229 | 50,2833  | 57,15     | 227       | Asia/Aqtobe      | 01.01.1932   | 22.11.2025  |
# | Panfilov      | KZ      | ALM    | 36859 | 44,1667  | 80,0667   | 640       | Asia/Almaty      | 14.01.1946   | 02.04.2025  |
# | Balhash       | KZ      | KAR    | 35796 | 46,8     | 75,0833   | 352       | Asia/Almaty      | 01.01.1948   | 02.04.2025  |
# | Atbasar       | KZ      | AKM    | 35078 | 51,8167  | 68,3667   | 308       | Asia/Qyzylorda   | 01.01.1948   | 02.04.2025  |

# %%
wmo_lists = ['38328','36177','35229','36859','35796','35078']

# %%
from meteostat import Hourly
from datetime import datetime

# %%
all_data = []
start = datetime(1950, 1, 1)
end = datetime(2025, 1, 1)
for station_id in wmo_lists:
    print(f"Loading: {station_id}")
    data = Hourly(station_id, start, end).fetch()
    data['station'] = station_id
    all_data.append(data)


df_weather = pd.concat(all_data)
# Out:
# Loading: 38328
# Warning: Cannot load hourly/1964/38328.csv.gz from https://data.meteostat.net/
# Warning: Cannot load hourly/1965/38328.csv.gz from https://data.meteostat.net/
# Warning: Cannot load hourly/1966/38328.csv.gz from https://data.meteostat.net/
# Warning: Cannot load hourly/1967/38328.csv.gz from https://data.meteostat.net/
# Warning: Cannot load hourly/1968/38328.csv.gz from https://data.meteostat.net/
# Warning: Cannot load hourly/1972/38328.csv.gz from https://data.meteostat.net/
# Loading: 36177
# Warning: Cannot load hourly/1972/36177.csv.gz from https://data.meteostat.net/
# Loading: 35229
# Warning: Cannot load hourly/1972/35229.csv.gz from https://data.meteostat.net/
# Loading: 36859
# Warning: Cannot load hourly/1972/36859.csv.gz from https://data.meteostat.net/
# Loading: 35796
# Warning: Cannot load hourly/1972/35796.csv.gz from https://data.meteostat.net/
# Loading: 35078
# Warning: Cannot load hourly/1972/35078.csv.gz from https://data.meteostat.net/

# %%
df_weather.head()
# Out:
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 1950-01-01 00:00:00  -2.2  -2.8  96.0  <NA>  <NA>  250.0  42.5  <NA>  1022.6
# 1950-01-01 06:00:00  -2.2  <NA>  <NA>  <NA>  <NA>  220.0  25.9  <NA>  1027.0
# 1950-01-01 12:00:00  -2.2  -3.9  88.0  <NA>  <NA>    0.0   0.0  <NA>  1026.0
# 1950-01-01 18:00:00  -3.9  -6.0  85.0  <NA>  <NA>   40.0   3.6  <NA>  1023.9
# 1950-01-02 00:00:00  -3.9 -11.2  57.0  <NA>  <NA>   90.0  11.2  <NA>  1024.4
#
#                      tsun  coco station
# time
# 1950-01-01 00:00:00  <NA>  <NA>   38328
# 1950-01-01 06:00:00  <NA>  <NA>   38328
# 1950-01-01 12:00:00  <NA>  <NA>   38328
# 1950-01-01 18:00:00  <NA>  <NA>   38328
# 1950-01-02 00:00:00  <NA>  <NA>   38328

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1392038 entries, 1950-01-01 00:00:00 to 2025-01-01 00:00:00
# Data columns (total 12 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   temp     1382975 non-null  Float64
#  1   dwpt     1373904 non-null  Float64
#  2   rhum     1373904 non-null  Float64
#  3   prcp     203992 non-null   Float64
#  4   snow     0 non-null        Float64
#  5   wdir     1359628 non-null  Float64
#  6   wspd     1356750 non-null  Float64
#  7   wpgt     0 non-null        Float64
#  8   pres     1200715 non-null  Float64
#  9   tsun     0 non-null        Float64
#  10  coco     186547 non-null   Float64
#  11  station  1392038 non-null  object
# dtypes: Float64(11), object(1)
# memory usage: 152.7+ MB

# %%
df_weather.to_parquet("df_Daily.parquet", index=True)

# %%
meteostations=meteostations[meteostations['wmo'].isin(wmo_lists)]

# %%
meteostations.to_parquet("kz_meteostations_ref.parquet", index=True)

# %% [markdown]
# ## Step 2. Comparative climate analysis
#
# In this step, we compare long-term temperature trends in Kazakhstan with several reference regions that represent different climate drivers:
#
# - **Western Europe (North Atlantic region)**
#   Chosen to evaluate the stabilizing effect of the Atlantic Ocean and the Gulf Stream on long-term temperature variability.
#
# - **Central United States**
#   Selected as a continental climate analogue to Kazakhstan, allowing assessment of temperature trends under similar land-dominated conditions.
#
# - **Japan / South Korea**
#   Representing a Pacific ocean-influenced climate, characterized by strong oceanic and monsoonal effects.
#
# The objective of this comparison is to evaluate whether continental regions exhibit stronger long-term warming trends and higher temperature variability compared to ocean-influenced regions.

# %% [markdown]
# ### European Atlantic reference stations
#
# To represent Atlantic-influenced European climates, two coastal stations at contrasting latitudes were selected:
#
# - **Bergen (Norway)** — representing a cold, strongly oceanic climate with significant influence from the Gulf Stream.
# - **Lisbon (Portugal)** — representing a warm Atlantic climate with partial Mediterranean characteristics.
#
# Although Lisbon exhibits seasonal dry periods typical of southern Europe, both stations are directly influenced by the Atlantic Ocean. This allows evaluation of how ocean-driven climate systems maintain relative temperature stability across different latitudes, compared to continental regions such as Kazakhstan.

# %%
stations = Stations()
stations = stations.region('NO')

'Stations in Norway:', stations.count()
# Out:
# ('Stations in Norway:', 192)

# %%
meteostations_No = stations.fetch()

# %%
meteostations_No
# Out:
#                              name country region    wmo  icao  latitude  \
# id
# 01001                   Jan Mayen      NO   <NA>  01001  ENJA   70.9333
# 01002                    Grahuken      NO     SJ  01002  <NA>   79.7833
# 01003                    Hornsund      NO   <NA>  01003  <NA>   77.0000
# 01004              New Alesund II      NO     SJ  01004  ENAS   78.9167
# 01005                 Barentsburg      NO     SJ  01005  <NA>   78.0667
# ...                           ...     ...    ...    ...   ...       ...
# ENQC0            Troll C Platform      NO   <NA>   <NA>  ENQC   60.8858
# ENSF0           Statfjord Oil Rig      NO   <NA>   <NA>  ENSF   61.2167
# ENSL0         Sleipner A Platform      NO   <NA>   <NA>  ENSL   58.3667
# ENSO0         Stord / Foldrøyhamn      NO     HO   <NA>  ENSO   59.8000
# ENVR0  Værøy / Vaeroy / Røsnesvåg      NO     NO   <NA>  ENVR   67.6554
#
#        longitude  elevation             timezone hourly_start hourly_end  \
# id
# 01001    -8.6667       10.0          Europe/Oslo   1931-01-01 2025-03-20
# 01002    14.4667        0.0          Europe/Oslo   1986-11-09 2025-03-20
# 01003    15.5000       10.0          Europe/Oslo   1985-06-01 2025-03-20
# 01004    11.9333        8.0          Europe/Oslo   1973-01-01 2014-05-23
# 01005    13.6333        9.0  Arctic/Longyearbyen          NaT        NaT
# ...          ...        ...                  ...          ...        ...
# ENQC0     3.6097    -9999.0          Europe/Oslo   2011-05-12 2025-05-14
# ENSF0     1.8333       15.0          Europe/Oslo   1984-12-04 2025-05-14
# ENSL0     1.9069    -9999.0          Europe/Oslo   2009-02-01 2025-05-14
# ENSO0     5.3500       49.0          Europe/Oslo   1986-11-25 2025-12-14
# ENVR0    12.7270        4.0          Europe/Oslo   2011-09-28 2025-12-14
#
#       daily_start  daily_end monthly_start monthly_end
# id
# 01001  1921-12-31 2025-10-30    1922-01-01  2022-01-01
# 01002  2010-10-07 2020-08-17           NaT         NaT
# 01003  2009-11-26 2020-08-31    2016-01-01  2017-01-01
# 01004  1968-12-31 1997-03-01    1969-01-01  1974-01-01
# 01005         NaT        NaT    1951-01-01  1980-01-01
# ...           ...        ...           ...         ...
# ENQC0  2011-05-13 2022-03-06    2011-01-01  2021-01-01
# ENSF0  1987-09-21 2022-03-06    2010-01-01  2020-01-01
# ENSL0  2010-12-08 2022-03-06    2020-01-01  2021-01-01
# ENSO0  2020-01-20 2022-04-26           NaT         NaT
# ENVR0  2011-09-29 2020-06-14    2012-01-01  2019-01-01
#
# [192 rows x 15 columns]

# %%
meteostations_No = meteostations_No[
    meteostations_No['name'].str.contains('Bergen', case=False, na=False)
]

# %%
meteostations_No=meteostations_No.reset_index()

# %%
meteostations_No
# Out:
#       id              name country region    wmo  icao  latitude  longitude  \
# 0  01317  Bergen / Florida      NO     HO  01317  <NA>   60.3833     5.3333
#
#    elevation     timezone hourly_start hourly_end daily_start  daily_end  \
# 0       12.0  Europe/Oslo   1973-01-01 2025-03-21  1957-01-01 2025-10-31
#
#   monthly_start monthly_end
# 0    1957-01-01  2022-01-01

# %%
stations = Stations()
stations = stations.region('PT')

'Stations in Portugal:', stations.count()
# Out:
# ('Stations in Portugal:', 39)

# %%
meteostations_Pt = stations.fetch()

# %%
meteostations_Pt
# Out:
#                                  name country region    wmo  icao  latitude  \
# id
# 08000                    Água de Pena      PT     MA  08000  LPMA   32.7000
# 08501                   Flores Acores      PT     AZ  08501  LPFL   39.4500
# 08502                    Corvo Acores      PT     AZ  08502  LPCR   39.6667
# 08505   Horta / Castelo Branco Acores      PT     AZ  08505  LPHR   38.5167
# 08506                    Horta Acores      PT     AZ  08506  <NA>   38.5167
# 08509                    Lajes Acores      PT     AZ  08509  LPLA   38.7667
# 08512  Ponta Delgada / Nordela Acores      PT     AZ  08512  LPPD   37.7333
# 08513     Ponta Delgada / Obs. Acores      PT     AZ  08513  <NA>   37.7500
# 08515              Santa Maria Acores      PT     AZ  08515  LPAZ   36.9667
# 08521           Funchal / S. Catarina      PT     MD  08521  LPFU   32.6833
# 08522                         Funchal      PT     MD  08522  <NA>   32.6333
# 08524                     Porto Santo      PT     MD  08524  LPPS   33.0667
# 08532                 Sintra / Granja      PT     LI  08532  LPST   38.8333
# 08534                         Montijo      PT     SE  08534  LPMT   38.7000
# 08535                   Lisboa / Geof      PT     LI  08535  <NA>   38.7167
# 08536                Lisboa / Portela      PT     LI  08536  LPPT   38.7667
# 08537                         Alverca      PT     LI  08537  LPAR   38.8833
# 08538                          Sagres      PT     FA  08538  <NA>   37.0000
# 08539                             Ota      PT     LI  08539  LPOT   39.1167
# 08540                      Monte Real      PT     LE  08540  LPMR   39.8333
# 08541            Sines / Montes Chaos      PT     SE  08541  <NA>   37.9500
# 08545           Porto / Pedras Rubras      PT     PO  08545  LPPR   41.2333
# 08546          Porto / Serra Do Pilar      PT     PO  08546  <NA>   41.1333
# 08547            Aveiro / São Jacinto      PT     AV  08547  LPAV   40.6500
# 08548              Coimbra / Cernache      PT     CO  08548  <NA>   40.1500
# 08549                         Coimbra      PT     CO  08549  <NA>   40.2000
# 08551        Viana Do Castelo / Areia      PT     VC  08551  <NA>   41.6333
# 08552                          Tancos      PT     SA  08552  LPTN   39.4833
# 08554                Faro / Aeroporto      PT     FA  08554  LPFR   37.0167
# 08557                           Evora      PT     EV  08557  <NA>   38.5667
# 08558                Evora / C. Coord      PT     EV  08558  <NA>   38.5333
# 08562                            Beja      PT     BJ  08562  LPBJ   38.0167
# 08567                       Vila Real      PT     VR  08567  LPVR   41.2667
# 08570                  Castelo Branco      PT     CB  08570  <NA>   39.8333
# 08571                      Portalegre      PT     PG  08571  <NA>   39.2833
# 08575                        Braganca      PT     BN  08575  LPBG   41.8000
# 08579          Lisboa / Gago Coutinho      PT     LI  08579  <NA>   38.7667
# LPCS0                 Cascais / Tires      PT     LI   <NA>  LPCS   38.7250
# LPOV0       Ovar / Praia de Cortegaça      PT     AV   <NA>  LPOV   40.9167
#
#        longitude  elevation          timezone hourly_start hourly_end  \
# id
# 08000   -16.7700       60.0  Atlantic/Madeira   2004-05-10 2025-12-15
# 08501   -31.1333       28.0   Atlantic/Azores   1978-12-01 2025-12-15
# 08502   -31.1167       18.0     Europe/Lisbon   2003-10-23 2025-02-04
# 08505   -28.7167       40.0   Atlantic/Azores   1976-02-01 2025-12-15
# 08506   -28.6333       60.0   Atlantic/Azores          NaT        NaT
# 08509   -27.1000       52.0   Atlantic/Azores   1947-01-01 2025-12-15
# 08512   -25.7000       71.0   Atlantic/Azores   1931-01-03 2025-12-15
# 08513   -25.6667       35.0   Atlantic/Azores          NaT        NaT
# 08515   -25.1667      100.0   Atlantic/Azores   1944-08-07 2025-12-15
# 08521   -16.7667       58.0  Atlantic/Madeira   1948-01-11 2025-12-15
# 08522   -16.9000       58.0  Atlantic/Madeira          NaT        NaT
# 08534  2006-01-12 2022-04-22           NaT         NaT
# 08535  1900-12-31 2025-05-19    1901-01-01  2021-01-01
# 08536  1973-01-13 2022-04-25    1949-01-01  2022-01-01
# 08537         NaT        NaT           NaT         NaT
# 08538         NaT        NaT           NaT         NaT
# 08539         NaT        NaT           NaT         NaT
# 08540  2001-10-04 2022-04-24           NaT         NaT
# 08541         NaT        NaT           NaT         NaT
# 08545  1973-01-08 2022-04-25    1963-01-01  2022-01-01
# 08546  1940-12-31 2025-04-10    1941-01-01  2022-01-01
# 08547         NaT        NaT           NaT         NaT
# 08548  1996-08-01 2024-04-08    1996-01-01  2021-01-01
# 08549  1900-12-31 2010-12-30    1901-01-01  1996-01-01
# 08551         NaT        NaT           NaT         NaT
# 08552         NaT        NaT           NaT         NaT
# 08554  1973-01-01 2023-10-28    1973-01-01  2022-01-01
# 08557         NaT        NaT    1988-01-01  1994-01-01
# 08558  1996-08-31 2024-12-30    1996-01-01  2022-01-01
# 08562  1940-12-31 2025-03-23    1941-01-01  2022-01-01
# 08567  1997-08-06 2022-03-28    2005-01-01  2021-01-01
# 08570  1990-10-11 2024-12-20    1996-01-01  2021-01-01
# 08571         NaT        NaT    1988-01-01  1994-01-01
# 08575  1940-12-31 2024-08-19    1941-01-01  2021-01-01
# 08579         NaT        NaT           NaT         NaT
# LPCS0  2020-01-15 2022-04-24    2020-01-01  2021-01-01
# LPOV0  2006-01-13 2019-10-10           NaT         NaT

# %%
meteostations_Pt=meteostations_Pt[meteostations_Pt['region']=='LI']

# %%
meteostations_Pt
# Out:
#                          name country region    wmo  icao  latitude  \
# id
# 08532         Sintra / Granja      PT     LI  08532  LPST   38.8333
# 08535           Lisboa / Geof      PT     LI  08535  <NA>   38.7167
# 08536        Lisboa / Portela      PT     LI  08536  LPPT   38.7667
# 08537                 Alverca      PT     LI  08537  LPAR   38.8833
# 08539                     Ota      PT     LI  08539  LPOT   39.1167
# 08579  Lisboa / Gago Coutinho      PT     LI  08579  <NA>   38.7667
# LPCS0         Cascais / Tires      PT     LI   <NA>  LPCS   38.7250
#
#        longitude  elevation       timezone hourly_start hourly_end  \
# id
# 08532    -9.3333      134.0  Europe/Lisbon   1990-10-01 2025-12-12
# 08535    -9.1500       77.0  Europe/Lisbon          NaT        NaT
# 08536    -9.1333      114.0  Europe/Lisbon   1931-01-03 2025-12-15
# 08537    -9.0333        3.0  Europe/Lisbon   1999-01-04 2025-12-14
# 08539    -8.9833       41.0  Europe/Lisbon   2024-12-13 2024-12-13
# 08579    -9.1333      104.0  Europe/Lisbon   2018-01-27 2025-06-16
# LPCS0    -9.3552       99.0  Europe/Lisbon   2020-01-14 2025-12-14
#
#       daily_start  daily_end monthly_start monthly_end
# id
# 08532  2006-01-12 2010-11-20           NaT         NaT
# 08535  1900-12-31 2025-05-19    1901-01-01  2021-01-01
# 08536  1973-01-13 2022-04-25    1949-01-01  2022-01-01
# 08537         NaT        NaT           NaT         NaT
# 08539         NaT        NaT           NaT         NaT
# 08579         NaT        NaT           NaT         NaT
# LPCS0  2020-01-15 2022-04-24    2020-01-01  2021-01-01

# %%
meteostations_Pt=meteostations_Pt[meteostations_Pt['name']=='Lisboa / Geof']

# %%
meteostations_Pt=meteostations_Pt.reset_index()

# %%
meteostations_Pt
# Out:
#       id           name country region    wmo  icao  latitude  longitude  \
# 0  08535  Lisboa / Geof      PT     LI  08535  <NA>   38.7167      -9.15
#
#    elevation       timezone hourly_start hourly_end daily_start  daily_end  \
# 0       77.0  Europe/Lisbon          NaT        NaT  1900-12-31 2025-05-19
#
#   monthly_start monthly_end
# 0    1901-01-01  2021-01-01

# %%
meteostations_Eu=pd.concat([meteostations_No,meteostations_Pt])

# %%
meteostations_Eu
# Out:
#       id              name country region    wmo  icao  latitude  longitude  \
# 0  01317  Bergen / Florida      NO     HO  01317  <NA>   60.3833     5.3333
# 0  08535     Lisboa / Geof      PT     LI  08535  <NA>   38.7167    -9.1500
#
#    elevation       timezone hourly_start hourly_end daily_start  daily_end  \
# 0       12.0    Europe/Oslo   1973-01-01 2025-03-21  1957-01-01 2025-10-31
# 0       77.0  Europe/Lisbon          NaT        NaT  1900-12-31 2025-05-19
#
#   monthly_start monthly_end
# 0    1957-01-01  2022-01-01
# 0    1901-01-01  2021-01-01

# %% [markdown]
# ## Central USA reference stations
#
# To represent the strongly continental climate of central North America, two stations at contrasting latitudes were selected:
#
# - **Northern station (e.g., Minneapolis, Minnesota)** — representing a cold continental climate with long winters, significant temperature variation, and moderate precipitation.
# - **Southern station (e.g., Dallas, Texas)** — representing a warmer continental climate with hotter summers, milder winters, and a different precipitation regime.
#
# Although both stations are located in the continental interior and far from oceans, they provide a useful contrast in latitude and climate intensity. This allows evaluation of how continental climate systems vary with latitude and seasonal extremes, which can then be compared to Kazakhstan’s similarly continental climate patterns.

# %%
stations = Stations()
stations = stations.region('US')

'Stations in USA:', stations.count()
# Out:
# ('Stations in USA:', 2701)

# %%
meteostations_USA = stations.fetch()

# %%
meteostations_USA
# Out:
#                                     name country region   wmo  icao  latitude  \
# id
# 04AEH                            Norwich      US     NY  <NA>  KOIC   42.5665
# 0MV8M                Hill Air Force Base      US     UT  <NA>  KHIF   41.1111
# 0NNEW  Effingham County Memorial Airport      US     IL  <NA>  K1H2   39.0706
# 0OBKP            Live Oak County Airport      US     TX  <NA>  K8T6   28.3628
# 0RJDR                     Hotel (Gurley)      US     NE  <NA>  K1HW   41.3200
# ...                                  ...     ...    ...   ...   ...       ...
# ZGK9P                Victorville Airport      US     CA  <NA>  KVCV   34.5972
# ZJ8AR                     India - Sidney      US     NE  <NA>  K1IW   41.0500
# ZNWZW         Columbus Municipal Airport      US     NE  <NA>  KOLU   41.4500
# ZUQJS          Ephraim-Gibraltar Airport      US     WI  <NA>  K3D2   45.1357
# ZYITU  Selfridge Air National Guard Base      US     MI  <NA>  KMTC   42.6046
#
#        longitude  elevation             timezone hourly_start hourly_end  \
# id
# 04AEH   -75.5242      312.0     America/New_York   2022-04-23 2025-12-15
# 0MV8M  -111.9623     1459.0       America/Denver   2022-04-23 2025-12-15
# 0NNEW   -88.5333      179.0      America/Chicago   2022-05-06 2025-12-15
# 0OBKP   -98.1165       39.0      America/Chicago   2022-05-06 2025-12-15
# 0RJDR  -102.8300     1263.0       America/Denver   2022-05-06 2025-12-15
# ...          ...        ...                  ...          ...        ...
# ZGK9P  -117.3828      876.0  America/Los_Angeles   2022-04-23 2025-12-14
# ZJ8AR  -102.8700     1293.0       America/Denver   2022-05-06 2025-12-15
# ZNWZW   -97.3333      440.0      America/Chicago   2022-04-23 2025-12-15
# ZUQJS   -87.1881      234.0    America/Menominee   2022-05-06 2025-12-15
# ZYITU   -82.8353      177.0      America/Detroit   2022-04-23 2025-12-15
#
#       daily_start  daily_end monthly_start monthly_end
# id
# 04AEH  2022-04-23 2022-04-26           NaT         NaT
# 0MV8M  2022-04-23 2022-04-25           NaT         NaT
# 0NNEW         NaT        NaT           NaT         NaT
# 0OBKP         NaT        NaT           NaT         NaT
# 0RJDR         NaT        NaT           NaT         NaT
# ...           ...        ...           ...         ...
# ZGK9P  2022-04-23 2022-04-23           NaT         NaT
# ZJ8AR         NaT        NaT           NaT         NaT
# ZNWZW  2022-04-24 2022-04-24           NaT         NaT
# ZUQJS         NaT        NaT           NaT         NaT
# ZYITU  2022-04-24 2022-04-25           NaT         NaT
#
# [2701 rows x 15 columns]

# %%
meteostations_USA=meteostations_USA[meteostations_USA['region'].isin(['MI','TX'])]

# %%
meteostations_USA_TX = meteostations_USA[
    (meteostations_USA['region'] == 'TX') & 
    (meteostations_USA['daily_start'].notna())
]

# %%
meteostations_USA_TX=meteostations_USA_TX.sort_values(by='daily_start')
meteostations_USA_TX.head(20)
# Out:
#                                               name country region    wmo  \
# id
# 72351                   Wichita Falls Sheppard Afb      US     TX  72351
# 72250                   Brownsville/South Padre Is      US     TX  72250
# 72263                                 Mathis Field      US     TX  72263
# 72260  Stephenville, Clark Field Municipal Airport      US     TX  72260
# 72265                Midland International Airport      US     TX  72265
# 72244                             Houston / Olcott      US     TX  72244
# KSKF0        San Antonio / Lackland Air Force Base      US     TX   <NA>
# 72270                El Paso International Airport      US     TX  72270
# KRND0  San Antonio / Universal City / Airport City      US     TX   <NA>
# 72254                  Camp Mabry/Austin City Asos      US     TX  72254
# 72258                              Dallas / Oldham      US     TX  72258
# 72256                        Waco Regional Airport      US     TX  72256
# KNBE0                    Dallas / Lakeland Heights      US     TX   <NA>
# 72255                    Victoria Regional Airport      US     TX  72255
# KHRL0              Harlingen / Santa Elena Colonia      US     TX   <NA>
# KHDO0                                        Hondo      US     TX   <NA>
# 72264                                        Marfa      US     TX  72264
# 72363              Amarillo International  Airport      US     TX  72363
# 69019                                Abilene / Tye      US     TX  69019
# 72267                Lubbock International Airport      US     TX  72267
#
#        icao  latitude  longitude  elevation         timezone hourly_start  \
# id
# 72363 2025-12-15  1943-03-01 2025-08-27    1943-01-01  2022-01-01
# 69019 2025-12-15  1943-12-02 2022-04-25    1944-01-01  1996-01-01
# 72267 2025-12-15  1945-08-10 2025-08-27    1946-01-01  2022-01-01

# %%
meteostations_USA_TX=meteostations_USA_TX[meteostations_USA_TX['name']=='Dallas / Oldham']
meteostations_USA_TX
# Out:
#                   name country region    wmo  icao  latitude  longitude  \
# id
# 72258  Dallas / Oldham      US     TX  72258  KDAL   32.8471   -96.8518
#
#        elevation         timezone hourly_start hourly_end daily_start  \
# id
# 72258      148.0  America/Chicago   1946-07-26 2025-12-15  1939-08-01
#
#        daily_end monthly_start monthly_end
# id
# 72258 2025-12-10    1939-01-01  2022-01-01

# %%
meteostations_USA_MI= meteostations_USA[
    (meteostations_USA['region'] == 'MI') & 
    (meteostations_USA['daily_start'].notna())
]

# %%
meteostations_USA_MI
# Out:
#                                               name country region    wmo  \
# id
# 72019                            Munsing Lakeshore      US     MI  72019
# 72034                          Frankfort / Elberta      US     MI  72034
# 72537                         Detroit Metropolitan      US     MI  72537
# 72538                                Copper Harbor      US     MI  72538
# 72539                         Capital City Airport      US     MI  72539
# ...                                            ...     ...    ...    ...
# KY310    West Branch / Twin Pines Mobile Home Park      US     MI   <NA>
# KY700  Ionia / Canterbury Estates Mobile Home Park      US     MI   <NA>
# KYIP0                             Detroit / Denton      US     MI   <NA>
# NO755                          Luce County Airport      US     MI   <NA>
# ZYITU            Selfridge Air National Guard Base      US     MI   <NA>
#
#        icao  latitude  longitude  elevation         timezone hourly_start  \
# id
# 72019  KP53   46.4167   -86.6500      187.0  America/Detroit   2006-01-01
# 72034  KFKS   44.6252   -86.2008      193.0  America/Detroit   2006-01-01
# 72537  KDTW   42.2333   -83.0000      195.0  America/Detroit   1942-08-01
# 72538  KP59   47.4667   -87.8833      191.0  America/Detroit   2006-01-01
# 72539  KLAN   42.7833   -84.5833      262.0  America/Detroit   1973-01-01
# ...     ...       ...        ...        ...              ...          ...
# KY310  KY31   44.2448   -84.1798      269.0  America/Detroit   2020-01-14
# KY700  KY70   42.9380   -85.0606      249.0  America/Detroit   2014-07-31
# KYIP0  KYIP   42.2393   -83.5310      218.0  America/Detroit   1973-01-01
# NO755  KERY   46.3111   -85.4572      265.0  America/Detroit   2022-04-23
# ZYITU  KMTC   42.6046   -82.8353      177.0  America/Detroit   2022-04-23
#
#       hourly_end daily_start  daily_end monthly_start monthly_end
# id
# 72019 2025-12-15  2006-01-01 2022-04-24    2006-01-01  2022-01-01
# 72034 2025-12-15  2006-01-01 2022-04-25    2006-01-01  2022-01-01
# 72537 2025-12-15  1942-08-01 2025-08-27    1942-01-01  2022-01-01
# 72538 2025-12-15  2004-11-11 2025-12-10    2004-01-01  2022-01-01
# 72539 2025-12-15  1948-01-01 2025-12-10    1948-01-01  2022-01-01
# ...          ...         ...        ...           ...         ...
# KY310 2025-12-15  2020-01-14 2022-04-25    2020-01-01  2022-01-01
# KY700 2025-12-15  2014-08-01 2022-04-25    2020-01-01  2022-01-01
# KYIP0 2025-12-15  1973-01-03 2022-04-24    2005-01-01  2022-01-01
# NO755 2025-12-15  2022-04-23 2022-04-25           NaT         NaT
# ZYITU 2025-12-15  2022-04-24 2022-04-25           NaT         NaT
#
# [78 rows x 15 columns]

# %%
meteostations_USA_MI=meteostations_USA_MI.sort_values(by='daily_start')
meteostations_USA_MI.head(20)
# Out:
#                                                     name country region  \
# id
# 72743                                          Marquette      US     MI
# 72648                                           Escanaba      US     MI
# 72636                            Muskegon County Airport      US     MI
# 72639                     Alpena County Regional Airport      US     MI
# 72734                              Sault Ste. Marie Muni      US     MI
# 72537                               Detroit Metropolitan      US     MI
# KBTL0        Battle Creek / Avenue A Mobile Home Estates      US     MI
# KOSC0    Oscoda / Whispering Woods Mobile Home Community      US     MI
# 72539                               Capital City Airport      US     MI
# 72744                         Hancock Houghton Cty. Memo      US     MI
# 72637                Flint Bishop International  Airport      US     MI
# 72540                                           Spickard      US     MI
# 72635                       Gerald R. Ford International      US     MI
# 72638                           Roscommon County Airport      US     MI
# KMBS0      Saginaw / Falconview Estates Mobile Home Park      US     MI
# KDET0                                Detroit / Hamtramck      US     MI
# KPLN0                                           Pellston      US     MI
# KTVC0  Traverse City / Treverse City [Misspelling] / ...      US     MI
# KYIP0                                   Detroit / Denton      US     MI
# KJXN0                    Jackson / Coffman Trailer Court      US     MI
#
#          wmo  icao  latitude  longitude  elevation         timezone  \
# id
# 72743  72743  KMQT   46.5333   -87.5500      434.0  America/Detroit
# 72648  72648  KESC   45.7500   -87.0333      180.0  America/Detroit
# 72636  72636  KMKG   43.1667   -86.2333      191.0  America/Detroit
# 72639  72639  KAPN   45.0833   -83.5667      210.0  America/Detroit
# 72734  72734  KANJ   46.4833   -84.3500      218.0  America/Detroit
# 72537  72537  KDTW   42.2333   -83.0000      195.0  America/Detroit
# KBTL0   <NA>  KBTL   42.3073   -85.2515      290.0  America/Detroit
# KOSC0   <NA>  KOSC   44.4515   -83.3942      193.0  America/Detroit
# 72539  72539  KLAN   42.7833   -84.5833      262.0  America/Detroit
# 72744  72744  KCMX   47.1667   -88.4833      334.0  America/Detroit
# 72637  72637  KFNT   42.9667   -83.0833      238.0  America/Detroit
# 72540  72540  KP35   40.2500   -93.7167      271.0  America/Chicago
# 72635  72635  KGRR   42.8833   -85.5167      242.0  America/Detroit
# 72638  72638  KHTL   44.3500   -84.6667      351.0  America/Detroit
# KMBS0   <NA>  KMBS   43.5329   -84.0796      204.0  America/Detroit
# KDET0   <NA>  KDET   42.4092   -83.0099      191.0  America/Detroit
# KPLN0   <NA>  KPLN   45.5709   -84.7967      220.0  America/Detroit
# KTVC0   <NA>  KTVC   44.7416   -85.5824      190.0  America/Detroit
# KYIP0   <NA>  KYIP   42.2393   -83.5310      218.0  America/Detroit
# KJXN0   <NA>  KJXN   42.2604   -84.4604      305.0  America/Detroit
#
#
#   monthly_start monthly_end
# 0    1939-01-01  2022-01-01
# 1    1857-01-01  2022-01-01

# %% [markdown]
# ## Japanese reference stations
# To capture the variation in Pacific-influenced climates across Japan, two stations at contrasting latitudes were selected:
#
# - Sapporo (Hokkaido) — representing a cold, snowy climate in northern Japan with a stronger continental influence during winter months.
# - Tokyo (Honshu) — representing a temperate climate in central-southern Japan with significant Pacific Ocean and monsoon influence, resulting in milder winters and warmer, humid summers.
#
# These two stations allow analysis of how ocean-driven climate systems in the Pacific region influence seasonal temperature stability across different latitudes, providing a point of comparison with continental Kazakhstan and Atlantic-influenced European stations.

# %%
stations = Stations()
stations = stations.region('JP')

'Stations in Japan:', stations.count()
# Out:
# ('Stations in Japan:', 278)

# %%
meteostations_Japan = stations.fetch()

# %%
meteostations_Japan
# Out:
#                                                  name country region    wmo  \
# id
# 47218                                        Tomisato      JP     HK  47218
# 47401                                        Wakkanai      JP     HK  47401
# 47402                                    Kitamiesashi      JP     HK  47402
# 47404                                          Haboro      JP     HK  47404
# 47405                                             Omu      JP     HK  47405
# ...                                               ...     ...    ...    ...
# RORH0                                        Hateruma      JP     ON   <NA>
# RORK0                     Kitadaito Island / Nakanoku      JP   <NA>   <NA>
# RORS0  Shimoji-Shima Island / Shimojishima / shimochi      JP     ON   <NA>
# RORT0                                   Tarama Island      JP   <NA>   <NA>
# RORY0                          Yoron Island / Chabana      JP   <NA>   <NA>
#
#        icao  latitude  longitude  elevation    timezone hourly_start  \
# id
# 47218  RJEO   42.0700   139.4500       36.0  Asia/Tokyo   1975-05-21
# 47401  <NA>   45.4167   141.6833        3.0  Asia/Tokyo          NaT
# 47402  <NA>   44.9333   142.5833        7.0  Asia/Tokyo          NaT
# 47404  <NA>   44.3667   141.7000        8.0  Asia/Tokyo          NaT
# 47405  <NA>   44.5833   142.9667       14.0  Asia/Tokyo          NaT
# ...     ...       ...        ...        ...         ...          ...
# RORH0  RORH   24.0667   123.8000       13.0  Asia/Tokyo   1979-09-13
# RORK0  RORK   25.9167   131.3333       22.0  Asia/Tokyo   1980-05-02
# RORS0  RORS   24.8333   125.1500       16.0  Asia/Tokyo   1979-10-16
# RORT0  RORT   24.6500   124.7000        9.0  Asia/Tokyo   1979-10-12
# RORY0  RORY   27.0500   128.4000       16.0  Asia/Tokyo   1979-09-14
#
#       hourly_end daily_start  daily_end monthly_start monthly_end
# id
# 47218 1999-02-28         NaT        NaT           NaT         NaT
# 47401        NaT  1951-01-01 2024-09-28    1938-01-01  2021-01-01
# 47402        NaT  1951-01-01 2025-06-09    1951-01-01  2020-01-01
# 47404        NaT  1951-01-01 2025-06-09    1951-01-01  2021-01-01
# 47405        NaT  1951-01-01 2025-06-09    1951-01-01  2020-01-01
# ...          ...         ...        ...           ...         ...
# RORH0 1999-01-29         NaT        NaT           NaT         NaT
# RORK0 2025-12-15  2019-03-19 2022-04-25    2020-01-01  2021-01-01
# RORS0 2025-12-15  2020-05-22 2022-04-01           NaT         NaT
# RORT0 2025-12-15         NaT        NaT           NaT         NaT
# RORY0 2025-12-15  2017-03-09 2022-04-25    2020-01-01  2021-01-01
#
# [278 rows x 15 columns]

# %%
meteostations_Japan= meteostations_Japan[meteostations_Japan['daily_start'].notna()].sort_values(by='daily_start')

# %%
meteostations_Japan=meteostations_Japan[meteostations_Japan['region'].isin(['HK','TK'])]

# %%
meteostations_Japan
# Out:
#                                           name country region    wmo  icao  \
# id
# 47420                                   Nemuro      JP     HK  47420  <NA>
# 47981                                  Iwojima      JP     TK  47981  RJAW
# 47425                               Chitose Ab      JP     HK  47425  RJCC
# 47660                             Tachikawa Ab      JP     TK  47660  RJTC
# 47642                                Yokota Ab      JP     TK  47642  RJTY
# 47675                                   Oshima      JP     TK  47675  <NA>
# 47401                                 Wakkanai      JP     HK  47401  <NA>
# 47678                              Hachijojima      JP     TK  47678  <NA>
# 47677                               Miyakejima      JP     TK  47677  <NA>
# 47662                                    Tokyo      JP     TK  47662  RJTD
# 47433                                  Kutchan      JP     HK  47433  <NA>
# 47430                                 Hakodate      JP     HK  47430  <NA>
# 47428                                   Esashi      JP     HK  47428  <NA>
# 47426                                  Urakawa      JP     HK  47426  <NA>
# 47423                                  Muroran      JP     HK  47423  RJCY
# 47418                                  Kushiro      JP     HK  47418  RJCS
# 47417                                  Obihiro      JP     HK  47417  <NA>
# 47413                                Iwamizawa      JP     HK  47413  <NA>
# 47412                                  Sapporo      JP     HK  47412  <NA>
# 47411                                    Otaru      JP     HK  47411  <NA>
# 47409                                 Abashiri      JP     HK  47409  <NA>
# 47407                                Asahikawa      JP     HK  47407  <NA>
# 47406                                    Rumoi      JP     HK  47406  <NA>
# 47405                                      Omu      JP     HK  47405  <NA>
# 47404                                   Haboro      JP     HK  47404  <NA>
# 47402                             Kitamiesashi      JP     HK  47402  <NA>
# 47424                                Tomakomai      JP     HK  47424  <NA>
# 47440                                    Hiroo      JP     HK  47440  <NA>
# 47434  Chitose Japanese Air Self Defense Force      JP     HK  47434  RJCJ
# 47737                       Miyakejima Airport      JP     TK  47737  RJTQ
# RJCT0                     Tokachi / Nishi-nij?      JP     HK   <NA>  RJCT
# 47477                             Asahikawa Ab      JP     HK  47477  RJCA
# 47479                               Sapporo Ab      JP     HK  47479  RJCO
# 47476                        Asahikawa Airport      JP     HK  47476  RJEC
# 47488                         Hakodate Airport      JP     HK  47488  RJCH
# 47489                          Kushiro Airport      JP     HK  47489  RJCK
# 47490                          Obihiro Airport      JP     HK  47490  RJCB
# 47441                         Wakkanai Airport      JP     HK  47441  RJCW
# 47483                     Nakashibetsu Airport      JP     HK  47483  RJCN
# 47481                       Memambetsu Airport      JP     HK  47481  RJCM
# 47474                         Mombetsu Airport      JP     HK  47474  RJEB
# 47735                           Oshima Airport      JP     TK  47735  RJTO
#
#        latitude  longitude  elevation    timezone hourly_start hourly_end  \
# id
# 47420   43.3333   145.5833       25.0  Asia/Tokyo          NaT        NaT
# %%
meteostations_Japan=meteostations_Japan[meteostations_Japan['name'].isin(['Nemuro','Tokyo'])]

# %%
meteostations_Japan=meteostations_Japan.reset_index()

# %%
meteostations_foreign=pd.concat([meteostations_USA,meteostations_Eu,meteostations_Japan])

# %%
meteostations_foreign
# Out:
#       id              name country region    wmo  icao  latitude  longitude  \
# 0  72258   Dallas / Oldham      US     TX  72258  KDAL   32.8471   -96.8518
# 1  72743         Marquette      US     MI  72743  KMQT   46.5333   -87.5500
# 0  01317  Bergen / Florida      NO     HO  01317  <NA>   60.3833     5.3333
# 0  08535     Lisboa / Geof      PT     LI  08535  <NA>   38.7167    -9.1500
# 0  47420            Nemuro      JP     HK  47420  <NA>   43.3333   145.5833
# 1  47662             Tokyo      JP     TK  47662  RJTD   35.6833   139.7667
#
#    elevation         timezone hourly_start hourly_end daily_start  daily_end  \
# 0      148.0  America/Chicago   1946-07-26 2025-12-15  1939-08-01 2025-12-10
# 1      434.0  America/Detroit   1973-01-01 2025-04-30  1857-09-01 2025-12-08
# 0       12.0      Europe/Oslo   1973-01-01 2025-03-21  1957-01-01 2025-10-31
# 0       77.0    Europe/Lisbon          NaT        NaT  1900-12-31 2025-05-19
# 0       25.0       Asia/Tokyo          NaT        NaT  1931-01-01 2025-01-23
# 1        5.0       Asia/Tokyo   1952-12-31 2025-06-17  1951-01-01 2025-04-09
#
#   monthly_start monthly_end
# 0    1939-01-01  2022-01-01
# 1    1857-01-01  2022-01-01
# 0    1957-01-01  2022-01-01
# 0    1901-01-01  2021-01-01
# 0    1880-01-01  2021-01-01
# 1    1875-01-01  2021-01-01

# %%
meteostations_foreign.to_parquet("foreign_meteostations_ref.parquet", index=False)

# %%
from meteostat import Daily
from datetime import datetime

# %%
all_data = []
start = datetime(1950, 1, 1)
end = datetime(2025, 1, 1)
for station_id in meteostations_foreign['wmo']:
    print(f"Loading: {station_id}")
    data = Daily(station_id, start, end).fetch()
    data['station'] = station_id
    all_data.append(data)


df_daily = pd.concat(all_data)
# Out:
# Loading: 72258
# Loading: 72743
# Loading: 01317
# Warning: Cannot load daily/1950/01317.csv.gz from https://data.meteostat.net/
# Warning: Cannot load daily/1951/01317.csv.gz from https://data.meteostat.net/
# Warning: Cannot load daily/1952/01317.csv.gz from https://data.meteostat.net/
# Warning: Cannot load daily/1953/01317.csv.gz from https://data.meteostat.net/
# Warning: Cannot load daily/1954/01317.csv.gz from https://data.meteostat.net/
# Warning: Cannot load daily/1955/01317.csv.gz from https://data.meteostat.net/
# Warning: Cannot load daily/1956/01317.csv.gz from https://data.meteostat.net/
# Loading: 08535
# Loading: 47420
# Warning: Cannot load daily/2005/47420.csv.gz from https://data.meteostat.net/
# Loading: 47662
# Warning: Cannot load daily/1950/47662.csv.gz from https://data.meteostat.net/
# Warning: Cannot load daily/2005/47662.csv.gz from https://data.meteostat.net/

# %%
df_daily.to_parquet("foreign_meteostations_daily.parquet", index=False)

# %%
df_daily=df_daily.reset_index()
